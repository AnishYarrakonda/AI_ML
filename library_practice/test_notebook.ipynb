# %%
import pandas as pd

# %%
cars = pd.read_csv("carsdata")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cars = pd.read_csv("carsdata")
#
# NameError: name 'pd' is not defined
